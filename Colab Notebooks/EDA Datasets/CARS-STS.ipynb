# %%
# !pip install -U pandas-profiling

# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

# %%
fileURL='https://github.com/UCM-GAIA/Context-Dataset/raw/master/datasets/Travel_STS/Data_STS.csv'
df = pd.read_csv(fileURL, sep='\t', lineterminator='\n')
# df = pd.read_csv('Data_STS.csv', sep='\t', lineterminator='\n')

# %%
df
# Out:
#              creationDate  userID  itemID  ...  category1 category2 category3
# 0                     NaN       1       1  ...          1       NaN       NaN
# 1                     NaN       2       2  ...          1       NaN       NaN
# 2                     NaN       2       2  ...          1       NaN       NaN
# 3                     NaN       2       2  ...          1       NaN       NaN
# 4                     NaN       2       2  ...          1       NaN       NaN
# ...                   ...     ...     ...  ...        ...       ...       ...
# 2529  03/04/2014 14:14:18     324      53  ...          4       NaN       NaN
# 2530  03/04/2014 14:14:18     324      46  ...          4       NaN       NaN
# 2531  03/04/2014 14:14:18     324      43  ...          4       NaN       NaN
# 2532  03/04/2014 14:14:18     324      56  ...          8       NaN       NaN
# 2533  03/04/2014 14:54:16     325      14  ...          4       NaN       NaN
#
# [2534 rows x 28 columns]

# %%
prof = ProfileReport(df)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='variables', max=28.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='correlations', max=6.0, style=ProgressStyle(description_w…
# /usr/local/lib/python3.6/dist-packages/pandas_profiling/model/correlations.py:134: UserWarning: There was an attempt to calculate the cramers correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"cramers": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/pandas-profiling/pandas-profiling/issues
# (include the error message: 'No data; `observed` has size 0.')
#   (include the error message: '{error}')"""
# HBox(children=(FloatProgress(value=0.0, description='interactions [continuous]', max=169.0, style=ProgressStyl…
# HBox(children=(FloatProgress(value=0.0, description='table', max=1.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='missing', max=4.0, style=ProgressStyle(description_width=…
# HBox(children=(FloatProgress(value=0.0, description='warnings', max=3.0, style=ProgressStyle(description_width…
# HBox(children=(FloatProgress(value=0.0, description='package', max=1.0, style=ProgressStyle(description_width=…
# HBox(children=(FloatProgress(value=0.0, description='build report structure', max=1.0, style=ProgressStyle(des…

# %%
prof
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#Count Nan values
df.isna().sum()
# Out:
# creationDate                793
# userID                        0
# itemID                        0
# rating                        0
# birthDate                  1428
# gender                     1122
# opennessToExperience        813
# conscientiousness           813
# extraversion                813
# agreeableness               813
# emotionalStability          813
# distance                   2079
# timeAvailable              2151
# temperature                2139
# crowdedness                2174
# knowledgeOfSurroundings    2177
# season                     2199
# budget                     2265
# daytime                    2256
# weather                    2307
# companion                  2332
# mood                       2360
# weekday                    2383
# travelGoal                 2431
# transport                  2453
# category1                     0
# category2                  2529
# category3                  2532
# dtype: int64

# %%
len(df.columns)
# Out:
# 28

# %%
len(df)
# Out:
# 2534

# %%
df.isna().sum().sum()
# Out:
# 44175

# %%
len(df)*(len(df.columns) -4) # Minus UserID, ItemID and Ratings (CREATIONDATA)
# Out:
# 60816

# %%
100*(df.isna().sum().sum())/(len(df)*(len(df.columns) -4))
# Out:
# 72.63713496448302

# %%
#Translate values to TEXT
# distance: far away, near by
# time available: half day, one day, more than one day
# temperature: burning, hot, warm, cool, cold, freezing
# crowdedness: crowded, not crowded, empty
# knowledge of surroundings: new to area, returning visitor, citizen of the area
# season: spring, summer, autumn, winter
# budget: budget traveler, price for quality, high spender
# daytime: morning, noon, afternoon, evening, night
# weather: clear sky, sunny, cloudy, rainy, thunderstorm, snowing
# companion: alone, with friends/colleagues, with family, with girlfriend/boyfriend, with children	
# mood: happy, sad, active, lazy
# weekday: weekday, weekend
# travel goal: visiting friends, business, religion, health care, social event, education, scenic/landscape, hedonistic/fun, activity/sport
# means of transport: no transportation means, a bicycle, a car, public transport

# %%
df2=df

# %%
df2['distance']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       1.0
#        ...
# 2529    NaN
# 2530    NaN
# 2531    NaN
# 2532    NaN
# 2533    NaN
# Name: distance, Length: 2534, dtype: float64
