# %%
# !pip install -U pandas-profiling

# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

# %%
fileURL='https://github.com/UCM-GAIA/Context-Dataset/raw/master/datasets/Mobile_Frappe/frappe/frappe.csv'
df = pd.read_csv(fileURL, sep='\t', lineterminator='\n')
# df = pd.read_csv('frappe.csv', sep='\t', lineterminator='\n')
# df = pd.ExcelFile('Data_InCarMusic.xlsx').parse('ContextualRating');

# %%
df
# Out:
#        user  item  cnt    daytime  ...  cost  weather        country  city
# 0         0     0    1    morning  ...  free    sunny  United States     0
# 1         1     1    7  afternoon  ...  free   cloudy          Spain     0
# 2         2     2    6    evening  ...  free   cloudy          Spain   369
# 3         3     3    1     sunset  ...  free  unknown  United States  1028
# 4         4     4  428      night  ...  free    sunny    Switzerland   147
# ...     ...   ...  ...        ...  ...   ...      ...            ...   ...
# 96198   110     0    5    evening  ...  free    sunny  United States     0
# 96199    37    16  101     sunset  ...  free   cloudy         Canada   128
# 96200   181    33  243  afternoon  ...  free   cloudy         Israel   454
# 96201   451   752    1    evening  ...  free    sunny  United States     0
# 96202   364   380    3    evening  ...  free   cloudy  United States     0
#
# [96203 rows x 11 columns]

# %%
# df.loc[ df.homework=='unknown', 'homework'] = np.NaN
# Country
df.loc[ df.city==0, 'city'] = np.NaN

for col in df.columns:
  df.loc[ df[col]=='unknown', col] = np.NaN
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
prof = ProfileReport(df)

# %%
prof
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#Count Nan values
df.isna().sum()
# Out:
# UserID                  0
# ItemID                  0
#  Rating                 0
# DrivingStyle         3659
# landscape            3507
# mood                 3606
# naturalphenomena     3616
# RoadType             3616
# sleepiness           3855
# trafficConditions    3613
# weather              3615
# dtype: int64

# %%
len(df.columns)
# Out:
# 28

# %%
len(df)
# Out:
# 2534

# %%
df.isna().sum().sum()
# Out:
# 44175

# %%
len(df)*(len(df.columns) -4) # Minus UserID, ItemID and Ratings (CREATIONDATA)
# Out:
# 60816

# %%
100*(df.isna().sum().sum())/(len(df)*(len(df.columns) -3))
# Out:
# 90.625
